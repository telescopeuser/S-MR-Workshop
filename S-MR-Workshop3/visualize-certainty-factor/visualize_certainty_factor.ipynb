# %% [markdown]
# ## Visualize Certainty Factor and Combined CF

# %% [markdown]
# By: Mr. Ian TAN e0380954@u.nus.edu & GU Zhan (Sam)

# %% [markdown]
# ### Case 1: CF1 >= 0 & CF2 >=0

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np
# %matplotlib inline
from pylab import meshgrid

# function to be plotted
def z_func(a, b):
    return (a+b*(1-a))

x1 = np.arange(1.0, 0, -0.1) # x1 >= 0 according to given conditions
x2 = np.arange(1.0, 0, -0.1) # x2 <= 1 according to given conditions
X1,X2 = meshgrid(x1, x2)
Z = z_func(X1, X2)
# set all values outside condition to nan
#Z[X1**2 - X2 - 3 > 0] = np.nan

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X1, X2, Z, rstride=1, cstride=1,vmin=0, vmax=np.nanmax(Z), 
                       cmap=plt.cm.RdBu,linewidth=0, antialiased=False)

ax.set_xlabel('Certainty Factor 1')
ax.set_ylabel('Certainty Factor 2')
ax.set_zlabel('Combined CF')
ax.view_init(elev=25, azim=-120)
#ax.set_ylim(0,10)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ### Case 2: CF1 <= 0 & CF2 <=0

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np
# %matplotlib inline
from pylab import meshgrid

# function to be plotted
def z_func(a, b):
    return (a + b*(1+a))

x1 = np.arange(-1.0, 0, 0.1) # x1 >= 0 according to given conditions
x2 = np.arange(-1.0, 0, 0.1) # x2 <= 1 according to given conditions
X1,X2 = meshgrid(x1, x2)
Z = z_func(X1, X2)
# set all values outside condition to nan
#Z[X1**2 - X2 - 3 > 0] = np.nan

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X1, X2, Z, rstride=1, cstride=1,vmin=-1, vmax=np.nanmax(Z), 
                       cmap=plt.cm.RdBu,linewidth=0, antialiased=False)

ax.set_xlabel('Certainty Factor 1')
ax.set_ylabel('Certainty Factor 2')
ax.set_zlabel('Combined CF')
ax.view_init(elev=25, azim=-120)
#ax.set_ylim(0,10)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ### Combined Visualiztion

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np
# %matplotlib inline
from pylab import meshgrid

# function to be plotted
def z_func(a, b):
    z = a
    for i in range(0, len(a)):
        for j in range(0, len(a[i])): # Now you realized that GU Zhan (Sam) is a bad programmer.
            if a[i][j] >= 0 and b[i][j] >= 0:
                z[i][j] = a[i][j] + b[i][j] * ( 1 - a[i][j] )
#                 print(z[i][j])
            if a[i][j] < 0 and b[i][j] < 0:
                z[i][j] = a[i][j] + b[i][j] * ( 1 + a[i][j] )
#                 print(z[i][j])
            if a[i][j] * b[i][j] <= 0:
                z[i][j] = ( a[i][j] + b[i][j] ) / ( 1 - min(abs(a[i][j]), abs(b[i][j])) )
#                 print(z[i][j])
            
#     print(z)
    return(z)

x1 = np.arange(-1.0, 1, 0.15) 
x2 = np.arange(-1.0, 1, 0.15) 
X1,X2 = meshgrid(x1, x2)
Z = z_func(X1, X2)
# set all values outside condition to nan
#Z[X1**2 - X2 - 3 > 0] = np.nan

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X1, X2, Z, rstride=1, cstride=1,vmin=-1, vmax=np.nanmax(Z), 
                       cmap=plt.cm.RdBu,linewidth=0, antialiased=False)

ax.set_xlabel('Certainty Factor 1')
ax.set_ylabel('Certainty Factor 2')
ax.set_zlabel('Combined CF')
ax.view_init(elev=25, azim=-120)
#ax.set_ylim(0,10)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Codes below have yet to be fine tuned to generate the right graph
#
#
# def f_func(a, b):
#     return (a+b*(1+a))
#
# x1 = np.arange(-1, 0, 0.01) # x1 >= 0 according to given conditions
# x2 = np.arange(-1, 0, 0.01) # x2 <= 1 according to given conditions
# X1,X2 = meshgrid(x1, x2)
# Z = f_func(X1, X2)
# # set all values outside condition to nan
# #Z[X1**2 - X2 - 3 > 0] = np.nan
#
# fig = plt.figure()
# ax = fig.gca(projection='3d')
# surf = ax.plot_surface(X1, X2, Z, rstride=1, cstride=1,vmin=0, vmax=np.nanmax(Z),
#                        cmap=plt.cm.RdBu,linewidth=0, antialiased=False)
#
# ax.set_xlabel('x-axis')
# ax.set_ylabel('y-axis')
# ax.set_zlabel('z-axis')
# ax.view_init(elev=25, azim=-120)
# #ax.set_ylim(0,10)
# fig.colorbar(surf, shrink=0.5, aspect=5)
# plt.show()
